# Datetime
# 2024-11-05 09:30:00-05:00  14460545
# 2024-11-05 09:32:00-05:00  24244527
# 2024-11-05 09:34:00-05:00  19642099
# 2024-11-05 09:36:00-05:00  16773801
# 2024-11-05 09:38:00-05:00  17344373
# ...                             ...
# 2024-12-04 15:50:00-05:00  27270000
# 2024-12-04 15:52:00-05:00  24201000
# 2024-12-04 15:54:00-05:00  40616000
# 2024-12-04 15:56:00-05:00  44184000
# 2024-12-04 15:58:00-05:00  95648000
#
# [3998 rows x 5 columns]

# %%
def create_obv(df: pd.DataFrame) -> pd.Series:
    temp = df.copy()
    
    temp['Change'] = temp['Close'].diff()
    temp['Direction'] = temp['Change'].apply(lambda x: 1 if x > 0 else (-1 if x < 0 else 0))
    temp['Volume_adj'] = temp['Volume'] * temp['Direction']
    temp['OBV'] = temp['Volume_adj'].cumsum()
    
    return temp['OBV']

# %%
sp500['OBV'] = create_obv(sp500)

sp500
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2024-11-05 09:30:00-05:00  5722.430176  5732.859863  5722.100098  5732.669922
# 2024-11-05 09:32:00-05:00  5732.750000  5737.229980  5732.750000  5737.060059
# 2024-11-05 09:34:00-05:00  5737.060059  5738.660156  5735.620117  5736.759766
# 2024-11-05 09:36:00-05:00  5736.580078  5740.200195  5735.040039  5739.890137
# 2024-11-05 09:38:00-05:00  5739.810059  5741.729980  5739.240234  5741.490234
# ...                                ...          ...          ...          ...
# 2024-12-04 15:50:00-05:00  6087.799805  6089.839844  6086.979980  6087.350098
# 2024-12-04 15:52:00-05:00  6087.509766  6087.560059  6086.029785  6086.209961
# 2024-12-04 15:54:00-05:00  6086.319824  6087.399902  6084.959961  6085.689941
# 2024-12-04 15:56:00-05:00  6085.649902  6087.049805  6085.279785  6087.049805
# 2024-12-04 15:58:00-05:00  6087.009766  6087.020020  6084.859863  6086.229980
#
#                              Volume         OBV
# Datetime
# 2024-11-05 09:30:00-05:00  14460545           0
# 2024-11-05 09:32:00-05:00  24244527    24244527
# 2024-11-05 09:34:00-05:00  19642099     4602428
# 2024-11-05 09:36:00-05:00  16773801    21376229
# 2024-11-05 09:38:00-05:00  17344373    38720602
# ...                             ...         ...
# 2024-12-04 15:50:00-05:00  27270000  1205360598
# 2024-12-04 15:52:00-05:00  24201000  1181159598
# 2024-12-04 15:54:00-05:00  40616000  1140543598
# 2024-12-04 15:56:00-05:00  44184000  1184727598
# 2024-12-04 15:58:00-05:00  95648000  1089079598
#
# [3998 rows x 6 columns]

# %%
def create_rsi(df: pd.DataFrame, n: int) -> int:
    
    delta = df['Close'].diff()
    
    gains = delta.where(delta > 0, 0)
    losses = delta.where(delta < 0, 0)
    
    avg_gain = gains.rolling(window=n, min_periods=n).mean()
    avg_loss = losses.rolling(window=n, min_periods=n).mean()
    
    rs = avg_gain / avg_loss
# 2024-12-04 15:52:00-05:00  24201000  1181159598  239.481213  6085.689941
# 2024-12-04 15:54:00-05:00  40616000  1140543598  340.677966  6087.049805
# 2024-12-04 15:56:00-05:00  44184000  1184727598  187.191614  6086.229980
#
#                            Target
# Datetime
# 2024-11-05 09:56:00-05:00       1
# 2024-11-05 09:58:00-05:00       1
# 2024-11-05 10:00:00-05:00       1
# 2024-11-05 10:02:00-05:00       0
# 2024-11-05 10:04:00-05:00       0
# ...                           ...
# 2024-12-04 15:48:00-05:00       0
# 2024-12-04 15:50:00-05:00       0
# 2024-12-04 15:52:00-05:00       0
# 2024-12-04 15:54:00-05:00       1
# 2024-12-04 15:56:00-05:00       0
#
# [3984 rows x 9 columns]

# %%
predictors = ['High', 'Low', 'Close', 'Volume', 'OBV', 'RSI']

X_train, X_test, y_train, y_test = train_test_split(sp500[predictors], sp500['Target'], test_size=0.2)

model = xgb.XGBClassifier(
    n_estimators=100, 
    max_depth=6, 
    learning_rate=0.2, 
    objective='binary:logistic'
)

# %%
print(X_train.isna().sum())  # Check for NaN values
print((X_train == float('inf')).sum())  # Check for inf values
print((X_train == float('-inf')).sum())  # Check for -inf values
# Out:
# High      0
# Low       0
# Close     0
# Volume    0
# OBV       0
# RSI       0
# dtype: int64
# High      0
# Low       0
# Close     0
# Volume    0
# OBV       0
# RSI       0
# dtype: int64
# High      0
# Low       0
# Close     0
# Volume    0
# OBV       0
# RSI       1
# dtype: int64

# %%
X_train = X_train.replace([float('inf'), float('-inf')], float('nan'))
X_train = X_train.dropna()

# %%
print(X_test.isna().sum())  # Check for NaN values
print((X_test == float('inf')).sum())  # Check for inf values
print((X_test == float('-inf')).sum())  # Check for -inf values
# Out:
# High      0
# Low       0
# Close     0
# Volume    0
# OBV       0
# RSI       0
# dtype: int64
# High      0
# Low       0
# Close     0
# Volume    0
# OBV       0
# RSI       0
# dtype: int64
# High      0
# Low       0
# Close     0
# Volume    0
# OBV       0
# RSI       0
# dtype: int64

# %%
valid_indices = X_train.index.intersection(y_train.index)
X_train = X_train.loc[valid_indices]
y_train = y_train.loc[valid_indices]

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (3186, 6)
# (3186,)

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
prediction = model.predict(X_test)

# %%
prediction = pd.Series(prediction, index=y_test.index)

# %%
prediction
# Out:
# Datetime
# 2024-11-25 14:44:00-05:00    1
# 2024-12-03 12:36:00-05:00    1
# 2024-11-25 15:16:00-05:00    0
# 2024-11-12 13:14:00-05:00    0
# 2024-11-11 12:40:00-05:00    0
#                             ..
# 2024-12-04 14:42:00-05:00    0
# 2024-11-26 09:30:00-05:00    1
# 2024-11-26 11:52:00-05:00    1
# 2024-11-14 09:40:00-05:00    0
# 2024-11-21 14:50:00-05:00    1
# Length: 797, dtype: int32

# %%
precision = precision_score(y_test, prediction)

print(precision)
# Out:
# 0.4988610478359909
